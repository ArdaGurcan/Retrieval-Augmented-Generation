# %%
import weaviate
import json
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

client = weaviate.Client(
    url = "http://localhost:8080",  # Replace with your Weaviate endpoint
    additional_headers = {
        "X-OpenAI-Api-Key": api_key
    }
)
# Out:
# /Volumes/development/Python/RAG/openai-env/lib/python3.12/site-packages/weaviate/warnings.py:158: DeprecationWarning: Dep016: You are using the Weaviate v3 client, which is deprecated.
#             Consider upgrading to the new and improved v4 client instead!
#             See here for usage: https://weaviate.io/developers/weaviate/client-libraries/python
#
#   warnings.warn(

# %%
# create manuscript collection
class_obj = {
    "class": "Manuscript",
    "vectorizer": "text2vec-openai",  # If set to "none" you must always provide vectors yourself. Could be any other "text2vec-*" also.
    "moduleConfig": {
        "text2vec-openai": {
          "model": "text-embedding-3-small",
          "type": "text",
        },
        "generative-openai": {}  # Ensure the `generative-openai` module is used for generative queries
    }
}

client.schema.delete_class("Manuscript")
client.schema.create_class(class_obj)

# %%
# split text into windows
def text_to_windows(text, window_size, overlap):
    char_length = len(text)
    windows = []
    start = 0
    while start < char_length:
        end = start + window_size
        if end >= char_length:
            windows.append(text[start:char_length])  # Append the last window
            break
        windows.append(text[start:end])
        start += (window_size - overlap)  # Move start up by window_size minus overlap
    return windows

window_size = 2048

overlap = 512

counter = 0

client.batch.configure(batch_size=100)  # Configure batch
# read json lines into database
with open("pubmed_author_manuscripts/small_pubmed_manuscripts.jsonl", "r", encoding="utf-8") as file:
    for line in file:
        # parse the json from line
        data = json.loads(line)
        # extract text property
        text = data.get("text", "")

        # Split text into windows
        text_windows = text_to_windows(text, window_size, overlap)

        counter += 1
        with client.batch as batch:  # Initialize a batch process
            chunk_counter = 0
            for text_chunk in text_windows:
                chunk_counter += 1
                properties = {
                    "text": text_chunk,
                }
                batch.add_data_object(
                    data_object=properties,
                    class_name="Manuscript"
                )
                print(f"added line {counter}, chunk {chunk_counter}")
# Out:
# added line 1, chunk 1
# added line 1, chunk 2
# added line 1, chunk 3
# added line 1, chunk 4
# added line 1, chunk 5
# added line 1, chunk 6
# added line 1, chunk 7
# added line 1, chunk 8
# added line 1, chunk 9
# added line 1, chunk 10
# added line 1, chunk 11
# added line 1, chunk 12
# added line 1, chunk 13
# added line 1, chunk 14
# added line 1, chunk 15
# added line 1, chunk 16
# added line 1, chunk 17
# added line 1, chunk 18
# added line 1, chunk 19
# added line 1, chunk 20
# added line 2, chunk 1
# added line 2, chunk 2
# added line 2, chunk 3
# added line 2, chunk 4
# added line 2, chunk 5
# added line 2, chunk 6
# added line 2, chunk 7
# added line 2, chunk 8
# added line 2, chunk 9
# added line 2, chunk 10
# added line 2, chunk 11
# added line 2, chunk 12
# added line 2, chunk 13
# added line 2, chunk 14
# added line 2, chunk 15
# added line 2, chunk 16
# added line 2, chunk 17
# added line 2, chunk 18
# added line 2, chunk 19
# added line 2, chunk 20
# added line 2, chunk 21
# added line 2, chunk 22
# added line 2, chunk 23
# added line 2, chunk 24
# added line 2, chunk 25
# added line 2, chunk 26
# added line 2, chunk 27
# added line 2, chunk 28
# added line 2, chunk 29
# added line 2, chunk 30
# added line 2, chunk 31
# added line 2, chunk 32
# added line 2, chunk 33
# added line 2, chunk 34
# added line 2, chunk 35
# added line 3, chunk 1
# added line 3, chunk 2
# added line 3, chunk 3
# added line 3, chunk 4
# added line 3, chunk 5
# added line 3, chunk 6
# added line 3, chunk 7
# added line 3, chunk 8
# added line 3, chunk 9
# added line 3, chunk 10
# added line 3, chunk 11
# added line 3, chunk 12
# added line 3, chunk 13
# added line 3, chunk 14
# added line 3, chunk 15
# added line 3, chunk 16
# added line 3, chunk 17
# added line 3, chunk 18
# added line 3, chunk 19
# added line 3, chunk 20
# added line 3, chunk 21
# added line 3, chunk 22
# added line 3, chunk 23
# added line 3, chunk 24
# added line 3, chunk 25
# added line 3, chunk 26
# added line 3, chunk 27
# added line 3, chunk 28
# added line 3, chunk 29
# added line 4, chunk 1
# added line 4, chunk 2
# added line 4, chunk 3
# added line 4, chunk 4
# added line 4, chunk 5
# added line 4, chunk 6
# added line 4, chunk 7
# added line 4, chunk 8
# added line 4, chunk 9
# added line 4, chunk 10
# added line 4, chunk 11
# added line 4, chunk 12
# added line 4, chunk 13
# added line 4, chunk 14
# added line 4, chunk 15
# added line 4, chunk 16
# added line 4, chunk 17
# added line 4, chunk 18
# added line 4, chunk 19
# added line 4, chunk 20
# added line 4, chunk 21
# added line 4, chunk 22
# added line 4, chunk 23
# added line 4, chunk 24
# added line 4, chunk 25
# added line 4, chunk 26
# added line 4, chunk 27
# added line 4, chunk 28
# added line 5, chunk 1
# added line 5, chunk 2
# added line 5, chunk 3
# added line 5, chunk 4
# added line 5, chunk 5
# added line 5, chunk 6
# added line 5, chunk 7
# added line 5, chunk 8
# added line 5, chunk 9
# added line 5, chunk 10
# added line 5, chunk 11
# added line 5, chunk 12
# added line 5, chunk 13
# added line 5, chunk 14
# added line 5, chunk 15
# added line 5, chunk 16
# added line 5, chunk 17
# added line 5, chunk 18
# added line 5, chunk 19
# added line 5, chunk 20
# added line 5, chunk 21
# added line 5, chunk 22
# added line 5, chunk 23
# added line 5, chunk 24
# added line 5, chunk 25
# added line 5, chunk 26
# added line 5, chunk 27
# added line 5, chunk 28
# added line 5, chunk 29
# added line 5, chunk 30
# added line 5, chunk 31
# added line 5, chunk 32
# added line 5, chunk 33
# added line 5, chunk 34
# added line 6, chunk 1
# added line 6, chunk 2
# added line 6, chunk 3
# added line 6, chunk 4
# added line 6, chunk 5
# added line 6, chunk 6
# added line 6, chunk 7
# added line 6, chunk 8
# added line 6, chunk 9
# added line 6, chunk 10
# added line 6, chunk 11
# added line 6, chunk 12
# added line 6, chunk 13
# added line 6, chunk 14
# added line 6, chunk 15
# added line 6, chunk 16
# added line 6, chunk 17
# added line 6, chunk 18
# added line 6, chunk 19
# added line 6, chunk 20
# added line 6, chunk 21
# added line 6, chunk 22
# added line 6, chunk 23
# added line 6, chunk 24
# added line 6, chunk 25
# added line 6, chunk 26
# added line 6, chunk 27
# added line 6, chunk 28
# added line 6, chunk 29
# added line 6, chunk 30
# added line 6, chunk 31
# added line 6, chunk 32
# added line 6, chunk 33
# added line 6, chunk 34
# added line 6, chunk 35
# added line 6, chunk 36
# added line 6, chunk 37
# added line 6, chunk 38
# added line 6, chunk 39
# added line 6, chunk 40
# added line 6, chunk 41
# added line 6, chunk 42
# added line 6, chunk 43
# added line 6, chunk 44
# added line 6, chunk 45
# added line 6, chunk 46
# added line 6, chunk 47
# added line 6, chunk 48
# added line 6, chunk 49
# added line 6, chunk 50
# added line 6, chunk 51
# added line 6, chunk 52
# added line 6, chunk 53
# added line 6, chunk 54
# added line 6, chunk 55
# added line 6, chunk 56
# added line 6, chunk 57
# added line 6, chunk 58
# added line 6, chunk 59
# added line 6, chunk 60
# added line 6, chunk 61
# added line 6, chunk 62
# added line 6, chunk 63
# added line 6, chunk 64
# added line 6, chunk 65
# added line 6, chunk 66
# added line 6, chunk 67
# added line 6, chunk 68
# added line 6, chunk 69
# added line 6, chunk 70
# added line 6, chunk 71
# added line 6, chunk 72
# added line 6, chunk 73
# added line 6, chunk 74
# added line 6, chunk 75
# added line 6, chunk 76
# added line 6, chunk 77
# added line 6, chunk 78
# added line 6, chunk 79
# added line 6, chunk 80
# added line 6, chunk 81
# added line 6, chunk 82
# added line 6, chunk 83
# added line 6, chunk 84
# added line 6, chunk 85
# added line 6, chunk 86
# added line 6, chunk 87
# added line 6, chunk 88
# added line 6, chunk 89
# added line 6, chunk 90
# added line 6, chunk 91
# added line 6, chunk 92
# added line 6, chunk 93
# added line 6, chunk 94
# added line 6, chunk 95
# added line 7, chunk 1
# added line 7, chunk 2
# added line 7, chunk 3
# added line 7, chunk 4
# added line 7, chunk 5
# added line 7, chunk 6
# added line 7, chunk 7
# added line 7, chunk 8
# added line 7, chunk 9
# added line 7, chunk 10
# added line 7, chunk 11
# added line 7, chunk 12
# added line 7, chunk 13
# added line 7, chunk 14
# added line 7, chunk 15
# added line 7, chunk 16
# added line 7, chunk 17
# added line 7, chunk 18
# added line 7, chunk 19
# added line 7, chunk 20
# added line 7, chunk 21
# added line 7, chunk 22
# added line 7, chunk 23
# added line 7, chunk 24
# added line 7, chunk 25
# added line 7, chunk 26
# added line 7, chunk 27
# added line 7, chunk 28
# added line 7, chunk 29
# added line 7, chunk 30
# added line 7, chunk 31
# added line 7, chunk 32
# added line 7, chunk 33
# added line 7, chunk 34
# added line 7, chunk 35
# added line 7, chunk 36
# added line 7, chunk 37
# added line 7, chunk 38
# added line 7, chunk 39
# added line 7, chunk 40
# added line 7, chunk 41
# added line 7, chunk 42
# added line 7, chunk 43
# added line 7, chunk 44
# added line 7, chunk 45
# added line 7, chunk 46
# added line 7, chunk 47
# added line 7, chunk 48
# added line 7, chunk 49
# added line 7, chunk 50
# added line 7, chunk 51
# added line 7, chunk 52
# added line 7, chunk 53
# added line 8, chunk 1
# added line 8, chunk 2
# added line 8, chunk 3
# added line 8, chunk 4
# added line 8, chunk 5
# added line 8, chunk 6
# added line 8, chunk 7
# added line 8, chunk 8
# added line 8, chunk 9
# added line 8, chunk 10
# added line 8, chunk 11
# added line 8, chunk 12
# added line 8, chunk 13
# added line 8, chunk 14
# added line 8, chunk 15
# added line 8, chunk 16
# added line 8, chunk 17
# added line 8, chunk 18
# added line 8, chunk 19
# added line 8, chunk 20
# added line 8, chunk 21
# added line 8, chunk 22
# added line 8, chunk 23
# added line 8, chunk 24
# added line 8, chunk 25
# added line 8, chunk 26
# added line 8, chunk 27
# added line 8, chunk 28
# added line 8, chunk 29
# added line 8, chunk 30
# added line 8, chunk 31
# added line 8, chunk 32
# added line 8, chunk 33
# added line 9, chunk 1
# added line 9, chunk 2
# added line 9, chunk 3
# added line 9, chunk 4
# added line 9, chunk 5
# added line 9, chunk 6
# added line 9, chunk 7
# added line 9, chunk 8
# added line 9, chunk 9
# added line 9, chunk 10
# added line 9, chunk 11
# added line 9, chunk 12
# added line 9, chunk 13
# added line 9, chunk 14
# added line 9, chunk 15
# added line 9, chunk 16
# added line 9, chunk 17
# added line 9, chunk 18
# added line 9, chunk 19
# added line 9, chunk 20
# added line 9, chunk 21
# added line 9, chunk 22
# added line 9, chunk 23
# added line 9, chunk 24
# added line 9, chunk 25
# added line 9, chunk 26
# added line 9, chunk 27
# added line 9, chunk 28
# added line 9, chunk 29
# added line 9, chunk 30
# added line 9, chunk 31
# added line 9, chunk 32
# added line 9, chunk 33
# added line 9, chunk 34
# added line 9, chunk 35
# added line 9, chunk 36
# added line 9, chunk 37
# added line 9, chunk 38
# added line 9, chunk 39
# added line 9, chunk 40
# added line 9, chunk 41
# added line 9, chunk 42
# added line 9, chunk 43
# added line 9, chunk 44
# added line 9, chunk 45
# added line 9, chunk 46
# added line 9, chunk 47
# added line 9, chunk 48
# added line 9, chunk 49
# added line 9, chunk 50
# added line 9, chunk 51
# added line 9, chunk 52
# added line 9, chunk 53
# added line 9, chunk 54
# added line 9, chunk 55
# added line 9, chunk 56
# added line 9, chunk 57
# added line 9, chunk 58
# added line 9, chunk 59
# added line 9, chunk 60
# added line 9, chunk 61
# added line 9, chunk 62
# added line 10, chunk 1
# added line 10, chunk 2
# added line 10, chunk 3
# added line 10, chunk 4
# added line 10, chunk 5
# added line 10, chunk 6
# added line 10, chunk 7
# added line 10, chunk 8
# added line 10, chunk 9
# added line 10, chunk 10
# added line 10, chunk 11
# added line 10, chunk 12
# added line 10, chunk 13
# added line 10, chunk 14
# added line 10, chunk 15
# added line 10, chunk 16
# added line 10, chunk 17
# added line 10, chunk 18
# added line 10, chunk 19
# added line 10, chunk 20
# added line 10, chunk 21
# added line 10, chunk 22
# added line 10, chunk 23
# added line 10, chunk 24
# added line 10, chunk 25
# added line 10, chunk 26
# added line 10, chunk 27
# added line 10, chunk 28
# added line 10, chunk 29
# added line 10, chunk 30
# added line 10, chunk 31
# added line 10, chunk 32
# added line 10, chunk 33
# added line 10, chunk 34
# added line 10, chunk 35
# added line 10, chunk 36
# added line 10, chunk 37
# added line 10, chunk 38
# added line 11, chunk 1
# added line 11, chunk 2
# added line 11, chunk 3
# added line 11, chunk 4
# added line 11, chunk 5
# added line 11, chunk 6
# added line 11, chunk 7
# added line 11, chunk 8
# added line 11, chunk 9
# added line 11, chunk 10
# added line 11, chunk 11
# added line 11, chunk 12
# added line 11, chunk 13
# added line 11, chunk 14
# added line 11, chunk 15
# added line 11, chunk 16
# added line 11, chunk 17
# added line 11, chunk 18
# added line 11, chunk 19
# added line 11, chunk 20
# added line 11, chunk 21
# added line 11, chunk 22
# added line 11, chunk 23
# added line 11, chunk 24
# added line 11, chunk 25
# added line 11, chunk 26
# added line 11, chunk 27
# added line 11, chunk 28
# added line 11, chunk 29
# added line 11, chunk 30
# added line 11, chunk 31
# added line 11, chunk 32
# added line 11, chunk 33
# added line 11, chunk 34
# added line 11, chunk 35
# added line 12, chunk 1
# added line 12, chunk 2
# added line 12, chunk 3
# added line 12, chunk 4
# added line 12, chunk 5
# added line 12, chunk 6
# added line 12, chunk 7
# added line 12, chunk 8
# added line 12, chunk 9
# added line 12, chunk 10
# added line 12, chunk 11
# added line 12, chunk 12
# added line 12, chunk 13
# added line 12, chunk 14
# added line 12, chunk 15
# added line 12, chunk 16
# added line 12, chunk 17
# added line 12, chunk 18
# added line 12, chunk 19
# added line 12, chunk 20
# added line 12, chunk 21
# added line 12, chunk 22
# added line 12, chunk 23
# added line 12, chunk 24
# added line 12, chunk 25
# added line 12, chunk 26
# added line 12, chunk 27
# added line 12, chunk 28
# added line 12, chunk 29
# added line 12, chunk 30
# added line 12, chunk 31
# added line 12, chunk 32
# added line 12, chunk 33
# added line 12, chunk 34
# added line 12, chunk 35
# added line 12, chunk 36
# added line 12, chunk 37
# added line 13, chunk 1
# added line 13, chunk 2
# added line 13, chunk 3
# added line 13, chunk 4
# added line 13, chunk 5
# added line 13, chunk 6
# added line 13, chunk 7
# added line 13, chunk 8
# added line 13, chunk 9
# added line 13, chunk 10
# added line 13, chunk 11
# added line 13, chunk 12
# added line 13, chunk 13
# added line 13, chunk 14
# added line 13, chunk 15
# added line 13, chunk 16
# added line 13, chunk 17
# added line 13, chunk 18
# added line 13, chunk 19
# added line 13, chunk 20
# added line 13, chunk 21
# added line 13, chunk 22
# added line 13, chunk 23
# added line 13, chunk 24
# added line 13, chunk 25
# added line 13, chunk 26
# added line 13, chunk 27
# added line 13, chunk 28
# added line 13, chunk 29
# added line 13, chunk 30
# added line 13, chunk 31
# added line 13, chunk 32
# added line 13, chunk 33
# added line 13, chunk 34
# added line 13, chunk 35
# added line 13, chunk 36
# added line 13, chunk 37
# added line 13, chunk 38
# added line 13, chunk 39
# added line 13, chunk 40
# added line 13, chunk 41
# added line 13, chunk 42
# added line 13, chunk 43
# added line 13, chunk 44
# added line 13, chunk 45
# added line 13, chunk 46
# added line 13, chunk 47
# added line 13, chunk 48
# added line 13, chunk 49
# added line 13, chunk 50
# added line 13, chunk 51
# added line 13, chunk 52
# added line 13, chunk 53
# added line 13, chunk 54
# added line 13, chunk 55
# added line 13, chunk 56
# added line 13, chunk 57
# added line 13, chunk 58
# added line 13, chunk 59
# added line 13, chunk 60
# added line 13, chunk 61
# added line 14, chunk 1
# added line 14, chunk 2
# added line 14, chunk 3
# added line 14, chunk 4
# added line 14, chunk 5
# added line 14, chunk 6
# added line 14, chunk 7
# added line 14, chunk 8
# added line 14, chunk 9
# added line 14, chunk 10
# added line 14, chunk 11
# added line 14, chunk 12
# added line 14, chunk 13
# added line 14, chunk 14
# added line 14, chunk 15
# added line 14, chunk 16
# added line 14, chunk 17
# added line 14, chunk 18
# added line 14, chunk 19
# added line 14, chunk 20
# added line 14, chunk 21
# added line 14, chunk 22
# added line 14, chunk 23
# added line 14, chunk 24
# added line 14, chunk 25
# added line 14, chunk 26
# added line 14, chunk 27
# added line 14, chunk 28
# added line 14, chunk 29
# added line 14, chunk 30
# added line 15, chunk 1
# added line 15, chunk 2
# added line 15, chunk 3
# added line 15, chunk 4
# added line 15, chunk 5
# added line 15, chunk 6
# added line 15, chunk 7
# added line 15, chunk 8
# added line 15, chunk 9
# added line 15, chunk 10
# added line 15, chunk 11
# added line 15, chunk 12
# added line 15, chunk 13
# added line 15, chunk 14
# added line 15, chunk 15
# added line 15, chunk 16
# added line 15, chunk 17
# added line 15, chunk 18
# added line 15, chunk 19
# added line 15, chunk 20
# added line 15, chunk 21
# added line 15, chunk 22
# added line 15, chunk 23
# added line 15, chunk 24
# added line 15, chunk 25
# added line 15, chunk 26
# added line 15, chunk 27
# added line 15, chunk 28
# added line 15, chunk 29
# added line 15, chunk 30
# added line 15, chunk 31
# added line 15, chunk 32
# added line 15, chunk 33
# added line 15, chunk 34
# added line 15, chunk 35
# added line 15, chunk 36
# added line 15, chunk 37
# added line 15, chunk 38
# added line 15, chunk 39
# added line 15, chunk 40
# added line 15, chunk 41
# added line 15, chunk 42
# added line 15, chunk 43
# added line 15, chunk 44
# added line 15, chunk 45
# added line 15, chunk 46
# added line 15, chunk 47
# added line 15, chunk 48
# added line 15, chunk 49
# added line 15, chunk 50
# added line 15, chunk 51
# added line 15, chunk 52
# added line 15, chunk 53
# added line 15, chunk 54
# added line 16, chunk 1
# added line 16, chunk 2
# added line 16, chunk 3
# added line 16, chunk 4
# added line 16, chunk 5
# added line 16, chunk 6
# added line 16, chunk 7
# added line 16, chunk 8
# added line 16, chunk 9
# added line 16, chunk 10
# added line 16, chunk 11
# added line 16, chunk 12
# added line 16, chunk 13
# added line 16, chunk 14
# added line 16, chunk 15
# added line 16, chunk 16
# added line 16, chunk 17
# added line 16, chunk 18
# added line 16, chunk 19
# added line 16, chunk 20
# added line 16, chunk 21
# added line 16, chunk 22
# added line 16, chunk 23
# added line 16, chunk 24
# added line 16, chunk 25
# added line 16, chunk 26
# added line 16, chunk 27
# added line 16, chunk 28
# added line 16, chunk 29
# added line 16, chunk 30
# added line 16, chunk 31
# added line 16, chunk 32
# added line 16, chunk 33
# added line 16, chunk 34
# added line 16, chunk 35
# added line 16, chunk 36
# added line 16, chunk 37
# added line 17, chunk 1
# added line 17, chunk 2
# added line 17, chunk 3
# added line 17, chunk 4
# added line 17, chunk 5
# added line 17, chunk 6
# added line 17, chunk 7
# added line 17, chunk 8
# added line 17, chunk 9
# added line 17, chunk 10
# added line 17, chunk 11
# added line 17, chunk 12
# added line 17, chunk 13
# added line 17, chunk 14
# added line 17, chunk 15
# added line 17, chunk 16
# added line 17, chunk 17
# added line 17, chunk 18
# added line 17, chunk 19
# added line 17, chunk 20
# added line 17, chunk 21
# added line 17, chunk 22
# added line 17, chunk 23
# added line 17, chunk 24
# added line 17, chunk 25
# added line 17, chunk 26
# added line 17, chunk 27
# added line 17, chunk 28
# added line 17, chunk 29
# added line 17, chunk 30
# added line 17, chunk 31
# added line 17, chunk 32
# added line 17, chunk 33
# added line 17, chunk 34
# added line 17, chunk 35
# added line 17, chunk 36
# added line 17, chunk 37
# added line 18, chunk 1
# added line 18, chunk 2
# added line 18, chunk 3
# added line 18, chunk 4
# added line 18, chunk 5
# added line 18, chunk 6
# added line 18, chunk 7
# added line 18, chunk 8
# added line 18, chunk 9
# added line 18, chunk 10
# added line 18, chunk 11
# added line 18, chunk 12
# added line 18, chunk 13
# added line 18, chunk 14
# added line 18, chunk 15
# added line 18, chunk 16
# added line 18, chunk 17
# added line 18, chunk 18
# added line 18, chunk 19
# added line 18, chunk 20
# added line 18, chunk 21
# added line 18, chunk 22
# added line 18, chunk 23
# added line 18, chunk 24
# added line 18, chunk 25
# added line 18, chunk 26
# added line 18, chunk 27
# added line 18, chunk 28
# added line 18, chunk 29
# added line 18, chunk 30
# added line 18, chunk 31
# added line 18, chunk 32
# added line 18, chunk 33
# added line 18, chunk 34
# added line 18, chunk 35
# added line 18, chunk 36
# added line 18, chunk 37
# added line 18, chunk 38
# added line 18, chunk 39
# added line 18, chunk 40
# added line 18, chunk 41
# added line 18, chunk 42
# added line 18, chunk 43
# added line 19, chunk 1
# added line 19, chunk 2
# added line 19, chunk 3
# added line 19, chunk 4
# added line 19, chunk 5
# added line 19, chunk 6
# added line 19, chunk 7
# added line 19, chunk 8
# added line 19, chunk 9
# added line 19, chunk 10
# added line 19, chunk 11
# added line 19, chunk 12
# added line 19, chunk 13
# added line 19, chunk 14
# added line 19, chunk 15
# added line 19, chunk 16
# added line 19, chunk 17
# added line 19, chunk 18
# added line 19, chunk 19
# added line 19, chunk 20
# added line 19, chunk 21
# added line 19, chunk 22
# added line 19, chunk 23
# added line 19, chunk 24
# added line 19, chunk 25
# added line 19, chunk 26
# added line 19, chunk 27
# added line 19, chunk 28
# added line 19, chunk 29
# added line 19, chunk 30
# added line 19, chunk 31
# added line 19, chunk 32
# added line 19, chunk 33
# added line 19, chunk 34
# added line 19, chunk 35
# added line 19, chunk 36
# added line 19, chunk 37
# added line 19, chunk 38
# added line 19, chunk 39
# added line 20, chunk 1
# added line 20, chunk 2
# added line 20, chunk 3
# added line 20, chunk 4
# added line 20, chunk 5
# added line 20, chunk 6
# added line 20, chunk 7
# added line 20, chunk 8
# added line 20, chunk 9
# added line 20, chunk 10
# added line 20, chunk 11
# added line 20, chunk 12
# added line 20, chunk 13
# added line 20, chunk 14
# added line 20, chunk 15
# added line 20, chunk 16
# added line 20, chunk 17
# added line 20, chunk 18
# added line 20, chunk 19
# added line 20, chunk 20
# added line 20, chunk 21
# added line 20, chunk 22
# added line 20, chunk 23
# added line 20, chunk 24
# added line 20, chunk 25
# added line 20, chunk 26
# added line 20, chunk 27
# added line 20, chunk 28
# added line 20, chunk 29
# added line 20, chunk 30
# added line 20, chunk 31
# added line 20, chunk 32
# added line 20, chunk 33
# added line 20, chunk 34
# added line 20, chunk 35
# added line 20, chunk 36
# added line 20, chunk 37
# added line 20, chunk 38
# added line 21, chunk 1
# added line 21, chunk 2
# added line 21, chunk 3
# added line 21, chunk 4
# added line 21, chunk 5
# added line 21, chunk 6
# added line 21, chunk 7
# added line 21, chunk 8
# added line 21, chunk 9
# added line 21, chunk 10
# added line 21, chunk 11
# added line 21, chunk 12
# added line 21, chunk 13
# added line 22, chunk 1
# added line 22, chunk 2
# added line 22, chunk 3
# added line 22, chunk 4
# added line 22, chunk 5
# added line 22, chunk 6
# added line 22, chunk 7
# added line 22, chunk 8
# added line 22, chunk 9
# added line 22, chunk 10
# added line 22, chunk 11
# added line 22, chunk 12
# added line 22, chunk 13
# added line 22, chunk 14
# added line 23, chunk 1
# added line 23, chunk 2
# added line 23, chunk 3
# added line 23, chunk 4
# added line 23, chunk 5
# added line 23, chunk 6
# added line 23, chunk 7
# added line 23, chunk 8
# added line 23, chunk 9
# added line 23, chunk 10
# added line 23, chunk 11
# added line 23, chunk 12
# added line 23, chunk 13
# added line 23, chunk 14
# added line 23, chunk 15
# added line 23, chunk 16
# added line 23, chunk 17
# added line 23, chunk 18
# added line 23, chunk 19
# added line 23, chunk 20
# added line 23, chunk 21
# added line 23, chunk 22
# added line 23, chunk 23
# added line 23, chunk 24
# added line 23, chunk 25
# added line 23, chunk 26
# added line 24, chunk 1
# added line 24, chunk 2
# added line 24, chunk 3
# added line 24, chunk 4
# added line 24, chunk 5
# added line 24, chunk 6
# added line 24, chunk 7
# added line 24, chunk 8
# added line 24, chunk 9
# added line 24, chunk 10
# added line 24, chunk 11
# added line 24, chunk 12
# added line 24, chunk 13
# added line 24, chunk 14
# added line 24, chunk 15
# added line 24, chunk 16
# added line 24, chunk 17
# added line 24, chunk 18
# added line 24, chunk 19
# added line 24, chunk 20
# added line 25, chunk 1
# added line 25, chunk 2
# added line 25, chunk 3
# added line 25, chunk 4
# added line 25, chunk 5
# added line 25, chunk 6
# added line 25, chunk 7
# added line 25, chunk 8
# added line 25, chunk 9
# added line 25, chunk 10
# added line 25, chunk 11
# added line 25, chunk 12
# added line 25, chunk 13
# added line 25, chunk 14
# added line 25, chunk 15
# added line 25, chunk 16
# added line 25, chunk 17
# added line 25, chunk 18
# added line 25, chunk 19
# added line 25, chunk 20
# added line 25, chunk 21
# added line 25, chunk 22
# added line 26, chunk 1
# added line 26, chunk 2
# added line 26, chunk 3
# added line 26, chunk 4
# added line 26, chunk 5
# added line 26, chunk 6
# added line 26, chunk 7
# added line 26, chunk 8
# added line 26, chunk 9
# added line 26, chunk 10
# added line 26, chunk 11
# added line 26, chunk 12
# added line 26, chunk 13
# added line 26, chunk 14
# added line 26, chunk 15
# added line 26, chunk 16
# added line 26, chunk 17
# added line 26, chunk 18
# added line 26, chunk 19
# added line 26, chunk 20
# added line 26, chunk 21
# added line 26, chunk 22
# added line 26, chunk 23
# added line 26, chunk 24
# added line 26, chunk 25
# added line 26, chunk 26
# added line 26, chunk 27
# added line 26, chunk 28
# added line 26, chunk 29
# added line 26, chunk 30
# added line 26, chunk 31
# added line 26, chunk 32
# added line 26, chunk 33
# added line 26, chunk 34
# added line 26, chunk 35
# added line 26, chunk 36
# added line 26, chunk 37
# added line 26, chunk 38
# added line 26, chunk 39
# added line 26, chunk 40
# added line 26, chunk 41
# added line 26, chunk 42
# added line 26, chunk 43
# added line 26, chunk 44
# added line 26, chunk 45
# added line 26, chunk 46
# added line 26, chunk 47
# added line 26, chunk 48
# added line 26, chunk 49
# added line 26, chunk 50
# added line 26, chunk 51
# added line 26, chunk 52
# added line 26, chunk 53
# added line 26, chunk 54
# added line 26, chunk 55
# added line 26, chunk 56
# added line 26, chunk 57
# added line 26, chunk 58
# added line 26, chunk 59
# added line 26, chunk 60
# added line 26, chunk 61
# added line 26, chunk 62
# added line 26, chunk 63
# added line 26, chunk 64
# added line 26, chunk 65
# added line 26, chunk 66
# added line 26, chunk 67
# added line 26, chunk 68
# added line 26, chunk 69
# added line 26, chunk 70
# added line 26, chunk 71
# added line 26, chunk 72
# added line 26, chunk 73
# added line 26, chunk 74
# added line 26, chunk 75
# added line 26, chunk 76
# added line 26, chunk 77
# added line 26, chunk 78
# added line 26, chunk 79
# added line 26, chunk 80
# added line 26, chunk 81
# added line 26, chunk 82
# added line 26, chunk 83
# added line 26, chunk 84
# added line 26, chunk 85
# added line 26, chunk 86
# added line 26, chunk 87
# added line 26, chunk 88
# added line 26, chunk 89
# added line 26, chunk 90
# added line 26, chunk 91
# added line 26, chunk 92
# added line 26, chunk 93
# added line 26, chunk 94
# added line 26, chunk 95
# added line 26, chunk 96
# added line 26, chunk 97
# added line 26, chunk 98
# added line 26, chunk 99
# added line 26, chunk 100
# added line 26, chunk 101
# added line 26, chunk 102
# added line 26, chunk 103
# added line 26, chunk 104
# added line 26, chunk 105
# added line 26, chunk 106
# added line 26, chunk 107
# added line 26, chunk 108
# added line 26, chunk 109
# added line 26, chunk 110
# added line 26, chunk 111
# added line 26, chunk 112
# added line 26, chunk 113
# added line 26, chunk 114
# added line 26, chunk 115
# added line 26, chunk 116
# added line 26, chunk 117
# added line 26, chunk 118
# added line 26, chunk 119
# added line 26, chunk 120
# added line 26, chunk 121
# added line 26, chunk 122
# added line 27, chunk 1
# added line 27, chunk 2
# added line 27, chunk 3
# added line 27, chunk 4
# added line 27, chunk 5
# added line 27, chunk 6
# added line 27, chunk 7
# added line 27, chunk 8
# added line 27, chunk 9
# added line 27, chunk 10
# added line 27, chunk 11
# added line 27, chunk 12
# added line 27, chunk 13
# added line 27, chunk 14
# added line 27, chunk 15
# added line 27, chunk 16
# added line 27, chunk 17
# added line 27, chunk 18
# added line 27, chunk 19
# added line 27, chunk 20
# added line 27, chunk 21
# added line 27, chunk 22
# added line 27, chunk 23
# added line 27, chunk 24
# added line 27, chunk 25
# added line 27, chunk 26
# added line 27, chunk 27
# added line 27, chunk 28
# added line 27, chunk 29
# added line 27, chunk 30
# added line 27, chunk 31
# added line 27, chunk 32
# added line 27, chunk 33
# added line 27, chunk 34
# added line 27, chunk 35
# added line 27, chunk 36
# added line 27, chunk 37
# added line 27, chunk 38
# added line 27, chunk 39
# added line 27, chunk 40
# added line 27, chunk 41
# added line 27, chunk 42
# added line 27, chunk 43
# added line 27, chunk 44
# added line 27, chunk 45
# added line 27, chunk 46
# added line 27, chunk 47
# added line 27, chunk 48
# added line 27, chunk 49
# added line 27, chunk 50
# added line 27, chunk 51
# added line 27, chunk 52
# added line 27, chunk 53
# added line 27, chunk 54
# added line 27, chunk 55
# added line 28, chunk 1
# added line 28, chunk 2
# added line 28, chunk 3
# added line 28, chunk 4
# added line 28, chunk 5
# added line 28, chunk 6
# added line 28, chunk 7
# added line 28, chunk 8
# added line 28, chunk 9
# added line 28, chunk 10
# added line 28, chunk 11
# added line 28, chunk 12
# added line 28, chunk 13
# added line 28, chunk 14
# added line 28, chunk 15
# added line 28, chunk 16
# added line 28, chunk 17
# added line 28, chunk 18
# added line 28, chunk 19
# added line 28, chunk 20
# added line 28, chunk 21
# added line 28, chunk 22
# added line 28, chunk 23
# added line 28, chunk 24
# added line 28, chunk 25
# added line 28, chunk 26
# added line 28, chunk 27
# added line 28, chunk 28
# added line 28, chunk 29
# added line 28, chunk 30
# added line 28, chunk 31
# added line 28, chunk 32
# added line 28, chunk 33
# added line 28, chunk 34
# added line 28, chunk 35
# added line 28, chunk 36
# added line 28, chunk 37
# added line 28, chunk 38
# added line 28, chunk 39
# added line 28, chunk 40
# added line 28, chunk 41
# added line 28, chunk 42
# added line 28, chunk 43
# added line 28, chunk 44
# added line 28, chunk 45
# added line 29, chunk 1
# added line 29, chunk 2
# added line 29, chunk 3
# added line 29, chunk 4
# added line 29, chunk 5
# added line 29, chunk 6
# added line 29, chunk 7
# added line 29, chunk 8
# added line 29, chunk 9
# added line 29, chunk 10
# added line 29, chunk 11
# added line 29, chunk 12
# added line 29, chunk 13
# added line 29, chunk 14
# added line 29, chunk 15
# added line 29, chunk 16
# added line 29, chunk 17
# added line 29, chunk 18
# added line 29, chunk 19
# added line 29, chunk 20
# added line 29, chunk 21
# added line 29, chunk 22
# added line 29, chunk 23
# added line 29, chunk 24
# added line 29, chunk 25
# added line 29, chunk 26
# added line 29, chunk 27
# added line 29, chunk 28
# added line 29, chunk 29
# added line 29, chunk 30
# added line 29, chunk 31
# added line 30, chunk 1
# added line 30, chunk 2
# added line 30, chunk 3
# added line 30, chunk 4
# added line 30, chunk 5
# added line 30, chunk 6
# added line 30, chunk 7
# added line 30, chunk 8
# added line 30, chunk 9
# added line 30, chunk 10
# added line 30, chunk 11
# added line 30, chunk 12
# added line 30, chunk 13
# added line 30, chunk 14
# added line 30, chunk 15
# added line 30, chunk 16
# added line 30, chunk 17
# added line 30, chunk 18
# added line 30, chunk 19
# added line 30, chunk 20
# added line 30, chunk 21
# added line 30, chunk 22
# added line 30, chunk 23
# added line 30, chunk 24
# added line 30, chunk 25
# added line 30, chunk 26
# added line 30, chunk 27
# added line 30, chunk 28
# added line 30, chunk 29
# added line 30, chunk 30
# added line 30, chunk 31
# added line 30, chunk 32
# added line 30, chunk 33
# added line 31, chunk 1
# added line 31, chunk 2
# added line 31, chunk 3
# added line 31, chunk 4
# added line 31, chunk 5
# added line 31, chunk 6
# added line 31, chunk 7
# added line 31, chunk 8
# added line 31, chunk 9
# added line 31, chunk 10
# added line 31, chunk 11
# added line 31, chunk 12
# added line 31, chunk 13
# added line 31, chunk 14
# added line 32, chunk 1
# added line 32, chunk 2
# added line 32, chunk 3
# added line 32, chunk 4
# added line 32, chunk 5
# added line 32, chunk 6
# added line 32, chunk 7
# added line 32, chunk 8
# added line 32, chunk 9
# added line 32, chunk 10
# added line 32, chunk 11
# added line 32, chunk 12
# added line 32, chunk 13
# added line 32, chunk 14
# added line 32, chunk 15
# added line 32, chunk 16
# added line 32, chunk 17
# added line 32, chunk 18
# added line 32, chunk 19
# added line 32, chunk 20
# added line 33, chunk 1
# added line 33, chunk 2
# added line 33, chunk 3
# added line 33, chunk 4
# added line 33, chunk 5
# added line 33, chunk 6
# added line 33, chunk 7
# added line 33, chunk 8
# added line 33, chunk 9
# added line 33, chunk 10
# added line 33, chunk 11
# added line 33, chunk 12
# added line 33, chunk 13
# added line 33, chunk 14
# added line 33, chunk 15
# added line 33, chunk 16
# added line 33, chunk 17
# added line 33, chunk 18
# added line 33, chunk 19
# added line 33, chunk 20
# added line 33, chunk 21
# added line 33, chunk 22
# added line 33, chunk 23
# added line 33, chunk 24
# added line 33, chunk 25
# added line 33, chunk 26
# added line 33, chunk 27
# added line 33, chunk 28
# added line 33, chunk 29
# added line 34, chunk 1
# added line 34, chunk 2
# added line 34, chunk 3
# added line 34, chunk 4
# added line 34, chunk 5
# added line 34, chunk 6
# added line 34, chunk 7
# added line 34, chunk 8
# added line 34, chunk 9
# added line 34, chunk 10
# added line 34, chunk 11
# added line 34, chunk 12
# added line 34, chunk 13
# added line 34, chunk 14
# added line 34, chunk 15
# added line 34, chunk 16
# added line 34, chunk 17
# added line 34, chunk 18
# added line 34, chunk 19
# added line 34, chunk 20
# added line 34, chunk 21
# added line 34, chunk 22
# added line 34, chunk 23
# added line 34, chunk 24
# added line 34, chunk 25
# added line 34, chunk 26
# added line 34, chunk 27
# added line 34, chunk 28
# added line 34, chunk 29
# added line 35, chunk 1
# added line 35, chunk 2
# added line 35, chunk 3
# added line 35, chunk 4
# added line 35, chunk 5
# added line 35, chunk 6
# added line 35, chunk 7
# added line 35, chunk 8
# added line 35, chunk 9
# added line 35, chunk 10
# added line 35, chunk 11
# added line 35, chunk 12
# added line 35, chunk 13
# added line 35, chunk 14
# added line 35, chunk 15
# added line 35, chunk 16
# added line 35, chunk 17
# added line 35, chunk 18
# added line 35, chunk 19
# added line 35, chunk 20
# added line 35, chunk 21
# added line 35, chunk 22
# added line 35, chunk 23
# added line 35, chunk 24
# added line 35, chunk 25
# added line 35, chunk 26
# added line 35, chunk 27
# added line 35, chunk 28
# added line 35, chunk 29
# added line 35, chunk 30
# added line 35, chunk 31
# added line 35, chunk 32
# added line 35, chunk 33
# added line 35, chunk 34
# added line 36, chunk 1
# added line 36, chunk 2
# added line 36, chunk 3
# added line 36, chunk 4
# added line 36, chunk 5
# added line 36, chunk 6
# added line 36, chunk 7
# added line 36, chunk 8
# added line 36, chunk 9
# added line 36, chunk 10
# added line 36, chunk 11
# added line 36, chunk 12
# added line 36, chunk 13
# added line 36, chunk 14
# added line 36, chunk 15
# added line 36, chunk 16
# added line 36, chunk 17
# added line 36, chunk 18
# added line 36, chunk 19
# added line 36, chunk 20
# added line 36, chunk 21
# added line 36, chunk 22
# added line 36, chunk 23
# added line 36, chunk 24
# added line 36, chunk 25
# added line 36, chunk 26
# added line 36, chunk 27
# added line 36, chunk 28
# added line 36, chunk 29
# added line 36, chunk 30
# added line 36, chunk 31
# added line 36, chunk 32
# added line 36, chunk 33
# added line 36, chunk 34
# added line 37, chunk 1
# added line 37, chunk 2
# added line 37, chunk 3
# added line 37, chunk 4
# added line 37, chunk 5
# added line 37, chunk 6
# added line 37, chunk 7
# added line 37, chunk 8
# added line 37, chunk 9
# added line 37, chunk 10
# added line 37, chunk 11
# added line 37, chunk 12
# added line 37, chunk 13
# added line 37, chunk 14
# added line 37, chunk 15
# added line 37, chunk 16
# added line 37, chunk 17
# added line 37, chunk 18
# added line 37, chunk 19
# added line 37, chunk 20
# added line 37, chunk 21
# added line 37, chunk 22
# added line 37, chunk 23
# added line 37, chunk 24
# added line 37, chunk 25
# added line 37, chunk 26
# added line 38, chunk 1
# added line 38, chunk 2
# added line 38, chunk 3
# added line 38, chunk 4
# added line 38, chunk 5
# added line 38, chunk 6
# added line 38, chunk 7
# added line 38, chunk 8
# added line 38, chunk 9
# added line 38, chunk 10
# added line 38, chunk 11
# added line 38, chunk 12
# added line 38, chunk 13
# added line 38, chunk 14
# added line 38, chunk 15
# added line 38, chunk 16
# added line 38, chunk 17
# added line 38, chunk 18
# added line 38, chunk 19
# added line 38, chunk 20
# added line 38, chunk 21
# added line 38, chunk 22
# added line 38, chunk 23
# added line 38, chunk 24
# added line 38, chunk 25
# added line 38, chunk 26
# added line 38, chunk 27
# added line 38, chunk 28
# added line 38, chunk 29
# added line 38, chunk 30
# added line 38, chunk 31
# added line 38, chunk 32
# added line 38, chunk 33
# added line 38, chunk 34
# added line 38, chunk 35
# added line 38, chunk 36
# added line 38, chunk 37
# added line 38, chunk 38
# added line 38, chunk 39
# added line 38, chunk 40
# added line 38, chunk 41
# added line 38, chunk 42
# added line 38, chunk 43
# added line 38, chunk 44
# added line 39, chunk 1
# added line 39, chunk 2
# added line 39, chunk 3
# added line 39, chunk 4
# added line 39, chunk 5
# added line 39, chunk 6
# added line 39, chunk 7
# added line 39, chunk 8
# added line 39, chunk 9
# added line 39, chunk 10
# added line 39, chunk 11
# added line 39, chunk 12
# added line 39, chunk 13
# added line 39, chunk 14
# added line 39, chunk 15
# added line 39, chunk 16
# added line 39, chunk 17
# added line 39, chunk 18
# added line 39, chunk 19
# added line 39, chunk 20
# added line 39, chunk 21
# added line 39, chunk 22
# added line 39, chunk 23
# added line 39, chunk 24
# added line 39, chunk 25
# added line 39, chunk 26
# added line 39, chunk 27
# added line 39, chunk 28
# added line 39, chunk 29
# added line 39, chunk 30
# added line 39, chunk 31
# added line 39, chunk 32
# added line 39, chunk 33
# added line 39, chunk 34
# added line 39, chunk 35
# added line 39, chunk 36
# added line 39, chunk 37
# added line 39, chunk 38
# added line 39, chunk 39
# added line 40, chunk 1
# added line 40, chunk 2
# added line 40, chunk 3
# added line 40, chunk 4
# added line 40, chunk 5
# added line 40, chunk 6
# added line 40, chunk 7
# added line 40, chunk 8
# added line 40, chunk 9
# added line 40, chunk 10
# added line 40, chunk 11
# added line 40, chunk 12
# added line 40, chunk 13
# added line 40, chunk 14
# added line 40, chunk 15
# added line 40, chunk 16
# added line 40, chunk 17
# added line 40, chunk 18
# added line 40, chunk 19
# added line 40, chunk 20
# added line 40, chunk 21
# added line 40, chunk 22
# added line 40, chunk 23
# added line 40, chunk 24
# added line 40, chunk 25
# added line 40, chunk 26
# added line 40, chunk 27
# added line 40, chunk 28
# added line 40, chunk 29
# added line 40, chunk 30
# added line 40, chunk 31
# added line 40, chunk 32
# added line 40, chunk 33
# added line 40, chunk 34
# added line 40, chunk 35
# added line 40, chunk 36
# added line 40, chunk 37
# added line 40, chunk 38
# added line 40, chunk 39
# added line 40, chunk 40
# added line 40, chunk 41
# added line 40, chunk 42
# added line 40, chunk 43
# added line 40, chunk 44
# added line 40, chunk 45
# added line 41, chunk 1
# added line 41, chunk 2
# added line 41, chunk 3
# added line 41, chunk 4
# added line 41, chunk 5
# added line 41, chunk 6
# added line 41, chunk 7
# added line 41, chunk 8
# added line 41, chunk 9
# added line 41, chunk 10
# added line 41, chunk 11
# added line 41, chunk 12
# added line 41, chunk 13
# added line 41, chunk 14
# added line 41, chunk 15
# added line 41, chunk 16
# added line 41, chunk 17
# added line 41, chunk 18
# added line 41, chunk 19
# added line 41, chunk 20
# added line 41, chunk 21
# added line 41, chunk 22
# added line 41, chunk 23
# added line 41, chunk 24
# added line 41, chunk 25
# added line 41, chunk 26
# added line 41, chunk 27
# added line 41, chunk 28
# added line 41, chunk 29
# added line 41, chunk 30
# added line 41, chunk 31
# added line 41, chunk 32
# added line 41, chunk 33
# added line 41, chunk 34
# added line 41, chunk 35
# added line 42, chunk 1
# added line 42, chunk 2
# added line 42, chunk 3
# added line 42, chunk 4
# added line 42, chunk 5
# added line 42, chunk 6
# added line 42, chunk 7
# added line 42, chunk 8
# added line 42, chunk 9
# added line 42, chunk 10
# added line 42, chunk 11
# added line 42, chunk 12
# added line 42, chunk 13
# added line 42, chunk 14
# added line 42, chunk 15
# added line 42, chunk 16
# added line 42, chunk 17
# added line 42, chunk 18
# added line 42, chunk 19
# added line 42, chunk 20
# added line 42, chunk 21
# added line 42, chunk 22
# added line 42, chunk 23
# added line 42, chunk 24
# added line 42, chunk 25
# added line 42, chunk 26
# added line 42, chunk 27
# added line 42, chunk 28
# added line 43, chunk 1
# added line 43, chunk 2
# added line 43, chunk 3
# added line 43, chunk 4
# added line 43, chunk 5
# added line 43, chunk 6
# added line 43, chunk 7
# added line 43, chunk 8
# added line 43, chunk 9
# added line 43, chunk 10
# added line 43, chunk 11
# added line 43, chunk 12
# added line 43, chunk 13
# added line 43, chunk 14
# added line 43, chunk 15
# added line 43, chunk 16
# added line 43, chunk 17
# added line 43, chunk 18
# added line 43, chunk 19
# added line 43, chunk 20
# added line 43, chunk 21
# added line 43, chunk 22
# added line 43, chunk 23
# added line 43, chunk 24
# added line 43, chunk 25
# added line 43, chunk 26
# added line 43, chunk 27
# added line 43, chunk 28
# added line 43, chunk 29
# added line 43, chunk 30
# added line 43, chunk 31
# added line 43, chunk 32
# added line 43, chunk 33
# added line 43, chunk 34
# added line 43, chunk 35
# added line 43, chunk 36
# added line 43, chunk 37
# added line 43, chunk 38
# added line 43, chunk 39
# added line 43, chunk 40
# added line 43, chunk 41
# added line 43, chunk 42
# added line 43, chunk 43
# added line 43, chunk 44
# added line 43, chunk 45
# added line 43, chunk 46
# added line 43, chunk 47
# added line 43, chunk 48
# added line 43, chunk 49
# added line 43, chunk 50
# added line 43, chunk 51
# added line 43, chunk 52
# added line 43, chunk 53
# added line 43, chunk 54
# added line 43, chunk 55
# added line 43, chunk 56
# added line 43, chunk 57
# added line 43, chunk 58
# added line 44, chunk 1
# added line 44, chunk 2
# added line 44, chunk 3
# added line 44, chunk 4
# added line 44, chunk 5
# added line 44, chunk 6
# added line 44, chunk 7
# added line 44, chunk 8
# added line 44, chunk 9
# added line 44, chunk 10
# added line 44, chunk 11
# added line 44, chunk 12
# added line 44, chunk 13
# added line 44, chunk 14
# added line 44, chunk 15
# added line 44, chunk 16
# added line 44, chunk 17
# added line 44, chunk 18
# added line 44, chunk 19
# added line 44, chunk 20
# added line 44, chunk 21
# added line 44, chunk 22
# added line 44, chunk 23
# added line 44, chunk 24
# added line 44, chunk 25
# added line 44, chunk 26
# added line 44, chunk 27
# added line 44, chunk 28
# added line 44, chunk 29
# added line 44, chunk 30
# added line 44, chunk 31
# added line 44, chunk 32
# added line 44, chunk 33
# added line 44, chunk 34
# added line 44, chunk 35
# added line 44, chunk 36
# added line 45, chunk 1
# added line 45, chunk 2
# added line 45, chunk 3
# added line 45, chunk 4
# added line 45, chunk 5
# added line 45, chunk 6
# added line 45, chunk 7
# added line 45, chunk 8
# added line 45, chunk 9
# added line 45, chunk 10
# added line 45, chunk 11
# added line 45, chunk 12
# added line 45, chunk 13
# added line 45, chunk 14
# added line 45, chunk 15
# added line 45, chunk 16
# added line 45, chunk 17
# added line 45, chunk 18
# added line 45, chunk 19
# added line 45, chunk 20
# added line 45, chunk 21
# added line 45, chunk 22
# added line 45, chunk 23
# added line 45, chunk 24
# added line 45, chunk 25
# added line 45, chunk 26
# added line 45, chunk 27
# added line 45, chunk 28
# added line 45, chunk 29
# added line 45, chunk 30
# added line 45, chunk 31
# added line 45, chunk 32
# added line 45, chunk 33
# added line 45, chunk 34
# added line 45, chunk 35
# added line 45, chunk 36
# added line 45, chunk 37
# added line 45, chunk 38
# added line 45, chunk 39
# added line 45, chunk 40
# added line 46, chunk 1
# added line 46, chunk 2
# added line 46, chunk 3
# added line 46, chunk 4
# added line 46, chunk 5
# added line 46, chunk 6
# added line 46, chunk 7
# added line 46, chunk 8
# added line 46, chunk 9
# added line 46, chunk 10
# added line 46, chunk 11
# added line 46, chunk 12
# added line 46, chunk 13
# added line 46, chunk 14
# added line 46, chunk 15
# added line 46, chunk 16
# added line 46, chunk 17
# added line 46, chunk 18
# added line 46, chunk 19
# added line 46, chunk 20
# added line 46, chunk 21
# added line 46, chunk 22
# added line 46, chunk 23
# added line 46, chunk 24
# added line 46, chunk 25
# added line 46, chunk 26
# added line 46, chunk 27
# added line 46, chunk 28
# added line 46, chunk 29
# added line 46, chunk 30
# added line 46, chunk 31
# added line 46, chunk 32
# added line 46, chunk 33
# added line 46, chunk 34
# added line 46, chunk 35
# added line 46, chunk 36
# added line 46, chunk 37
# added line 46, chunk 38
# added line 46, chunk 39
# added line 46, chunk 40
# added line 46, chunk 41
# added line 47, chunk 1
# added line 47, chunk 2
# added line 47, chunk 3
# added line 47, chunk 4
# added line 47, chunk 5
# added line 47, chunk 6
# added line 47, chunk 7
# added line 47, chunk 8
# added line 47, chunk 9
# added line 47, chunk 10
# added line 47, chunk 11
# added line 47, chunk 12
# added line 47, chunk 13
# added line 47, chunk 14
# added line 47, chunk 15
# added line 47, chunk 16
# added line 47, chunk 17
# added line 47, chunk 18
# added line 47, chunk 19
# added line 47, chunk 20
# added line 47, chunk 21
# added line 47, chunk 22
# added line 47, chunk 23
# added line 47, chunk 24
# added line 47, chunk 25
# added line 47, chunk 26
# added line 47, chunk 27
# added line 47, chunk 28
# added line 47, chunk 29
# added line 47, chunk 30
# added line 47, chunk 31
# added line 47, chunk 32
# added line 47, chunk 33
# added line 47, chunk 34
# added line 47, chunk 35
# added line 47, chunk 36
# added line 47, chunk 37
# added line 47, chunk 38
# added line 47, chunk 39
# added line 47, chunk 40
# added line 47, chunk 41
# added line 47, chunk 42
# added line 47, chunk 43
# added line 47, chunk 44
# added line 48, chunk 1
# added line 48, chunk 2
# added line 48, chunk 3
# added line 48, chunk 4
# added line 48, chunk 5
# added line 48, chunk 6
# added line 48, chunk 7
# added line 48, chunk 8
# added line 48, chunk 9
# added line 48, chunk 10
# added line 48, chunk 11
# added line 48, chunk 12
# added line 48, chunk 13
# added line 48, chunk 14
# added line 48, chunk 15
# added line 48, chunk 16
# added line 48, chunk 17
# added line 48, chunk 18
# added line 48, chunk 19
# added line 48, chunk 20
# added line 48, chunk 21
# added line 48, chunk 22
# added line 48, chunk 23
# added line 48, chunk 24
# added line 48, chunk 25
# added line 48, chunk 26
# added line 48, chunk 27
# added line 48, chunk 28
# added line 48, chunk 29
# added line 48, chunk 30
# added line 48, chunk 31
# added line 48, chunk 32
# added line 48, chunk 33
# added line 48, chunk 34
# added line 48, chunk 35
# added line 48, chunk 36
# added line 49, chunk 1
# added line 49, chunk 2
# added line 49, chunk 3
# added line 49, chunk 4
# added line 49, chunk 5
# added line 49, chunk 6
# added line 49, chunk 7
# added line 49, chunk 8
# added line 49, chunk 9
# added line 49, chunk 10
# added line 49, chunk 11
# added line 49, chunk 12
# added line 49, chunk 13
# added line 50, chunk 1
# added line 50, chunk 2
# added line 50, chunk 3
# added line 50, chunk 4
# added line 50, chunk 5
# added line 50, chunk 6
# added line 50, chunk 7
# added line 50, chunk 8
# added line 50, chunk 9
# added line 50, chunk 10
# added line 50, chunk 11
# added line 50, chunk 12
# added line 50, chunk 13
# added line 50, chunk 14
# added line 50, chunk 15
# added line 50, chunk 16
# added line 50, chunk 17
# added line 50, chunk 18
# added line 50, chunk 19
# added line 50, chunk 20
# added line 50, chunk 21
# added line 50, chunk 22
# added line 50, chunk 23
# added line 50, chunk 24
# added line 50, chunk 25
# added line 50, chunk 26
# added line 50, chunk 27
# added line 50, chunk 28
# added line 51, chunk 1
# added line 51, chunk 2
# added line 51, chunk 3
# added line 51, chunk 4
# added line 51, chunk 5
# added line 52, chunk 1
# added line 52, chunk 2
# added line 52, chunk 3
# added line 52, chunk 4
# added line 52, chunk 5
# added line 52, chunk 6
# added line 52, chunk 7
# added line 52, chunk 8
# added line 52, chunk 9
# added line 52, chunk 10
# added line 52, chunk 11
# added line 52, chunk 12
# added line 52, chunk 13
# added line 52, chunk 14
# added line 52, chunk 15
# added line 52, chunk 16
# added line 52, chunk 17
# added line 52, chunk 18
# added line 52, chunk 19
# added line 52, chunk 20
# added line 52, chunk 21
# added line 52, chunk 22
# added line 52, chunk 23
# added line 52, chunk 24
# added line 52, chunk 25
# added line 52, chunk 26
# added line 52, chunk 27
# added line 53, chunk 1
# added line 53, chunk 2
# added line 53, chunk 3
# added line 53, chunk 4
# added line 53, chunk 5
# added line 53, chunk 6
# added line 53, chunk 7
# added line 53, chunk 8
# added line 53, chunk 9
# added line 53, chunk 10
# added line 53, chunk 11
# added line 53, chunk 12
# added line 53, chunk 13
# added line 53, chunk 14
# added line 53, chunk 15
# added line 53, chunk 16
# added line 53, chunk 17
# added line 53, chunk 18
# added line 53, chunk 19
# added line 53, chunk 20
# added line 54, chunk 1
# added line 54, chunk 2
# added line 54, chunk 3
# added line 54, chunk 4
# added line 54, chunk 5
# added line 54, chunk 6
# added line 54, chunk 7
# added line 54, chunk 8
# added line 54, chunk 9
# added line 54, chunk 10
# added line 54, chunk 11
# added line 54, chunk 12
# added line 54, chunk 13
# added line 54, chunk 14
# added line 54, chunk 15
# added line 54, chunk 16
# added line 54, chunk 17
# added line 54, chunk 18
# added line 54, chunk 19
# added line 54, chunk 20
# added line 54, chunk 21
# added line 54, chunk 22
# added line 54, chunk 23
# added line 54, chunk 24
# added line 54, chunk 25
# added line 54, chunk 26
# added line 54, chunk 27
# added line 54, chunk 28
# added line 54, chunk 29
# added line 54, chunk 30
# added line 54, chunk 31
# added line 54, chunk 32
# added line 54, chunk 33
# added line 54, chunk 34
# added line 54, chunk 35
# added line 54, chunk 36
# added line 54, chunk 37
# added line 54, chunk 38
# added line 54, chunk 39
# added line 54, chunk 40
# added line 54, chunk 41
# added line 54, chunk 42
# added line 54, chunk 43
# added line 54, chunk 44
# added line 55, chunk 1
# added line 55, chunk 2
# added line 55, chunk 3
# added line 55, chunk 4
# added line 55, chunk 5
# added line 55, chunk 6
# added line 55, chunk 7
# added line 55, chunk 8
# added line 55, chunk 9
# added line 55, chunk 10
# added line 55, chunk 11
# added line 55, chunk 12
# added line 55, chunk 13
# added line 55, chunk 14
# added line 55, chunk 15
# added line 55, chunk 16
# added line 55, chunk 17
# added line 55, chunk 18
# added line 55, chunk 19
# added line 55, chunk 20
# added line 55, chunk 21
# added line 55, chunk 22
# added line 55, chunk 23
# added line 55, chunk 24
# added line 55, chunk 25
# added line 55, chunk 26
# added line 55, chunk 27
# added line 55, chunk 28
# added line 55, chunk 29
# added line 55, chunk 30
# added line 56, chunk 1
# added line 56, chunk 2
# added line 56, chunk 3
# added line 56, chunk 4
# added line 56, chunk 5
# added line 56, chunk 6
# added line 56, chunk 7
# added line 56, chunk 8
# added line 56, chunk 9
# added line 56, chunk 10
# added line 56, chunk 11
# added line 56, chunk 12
# added line 56, chunk 13
# added line 56, chunk 14
# added line 56, chunk 15
# added line 56, chunk 16
# added line 56, chunk 17
# added line 56, chunk 18
# ...
# added line 82, chunk 27
# added line 82, chunk 28
# added line 82, chunk 29
# added line 82, chunk 30
# added line 82, chunk 31
# added line 82, chunk 32
# added line 82, chunk 33
# added line 82, chunk 34
# added line 82, chunk 35
# added line 82, chunk 36
# added line 82, chunk 37
# added line 82, chunk 38
# added line 82, chunk 39
# added line 82, chunk 40
# added line 82, chunk 41
# added line 82, chunk 42
# added line 82, chunk 43
# added line 82, chunk 44
# added line 82, chunk 45
# added line 82, chunk 46
# added line 82, chunk 47
# added line 82, chunk 48
# added line 82, chunk 49
# added line 82, chunk 50
# added line 82, chunk 51
# added line 82, chunk 52
# added line 82, chunk 53
# added line 82, chunk 54
# added line 82, chunk 55
# added line 82, chunk 56
# added line 83, chunk 1
# added line 83, chunk 2
# added line 83, chunk 3
# added line 83, chunk 4
# added line 83, chunk 5
# added line 83, chunk 6
# added line 83, chunk 7
# added line 83, chunk 8
# added line 83, chunk 9
# added line 83, chunk 10
# added line 83, chunk 11
# added line 83, chunk 12
# added line 83, chunk 13
# added line 83, chunk 14
# added line 83, chunk 15
# added line 83, chunk 16
# added line 83, chunk 17
# added line 83, chunk 18
# added line 83, chunk 19
# added line 83, chunk 20
# added line 83, chunk 21
# added line 83, chunk 22
# added line 83, chunk 23
# added line 83, chunk 24
# added line 83, chunk 25
# added line 83, chunk 26
# added line 83, chunk 27
# added line 83, chunk 28
# added line 83, chunk 29
# added line 83, chunk 30
# added line 84, chunk 1
# added line 84, chunk 2
# added line 84, chunk 3
# added line 84, chunk 4
# added line 84, chunk 5
# added line 84, chunk 6
# added line 84, chunk 7
# added line 84, chunk 8
# added line 84, chunk 9
# added line 84, chunk 10
# added line 84, chunk 11
# added line 84, chunk 12
# added line 84, chunk 13
# added line 84, chunk 14
# added line 84, chunk 15
# added line 84, chunk 16
# added line 84, chunk 17
# added line 84, chunk 18
# added line 84, chunk 19
# added line 84, chunk 20
# added line 84, chunk 21
# added line 84, chunk 22
# added line 84, chunk 23
# added line 84, chunk 24
# added line 84, chunk 25
# added line 84, chunk 26
# added line 84, chunk 27
# added line 84, chunk 28
# added line 84, chunk 29
# added line 84, chunk 30
# added line 84, chunk 31
# added line 84, chunk 32
# added line 84, chunk 33
# added line 84, chunk 34
# added line 84, chunk 35
# added line 84, chunk 36
# added line 84, chunk 37
# added line 84, chunk 38
# added line 84, chunk 39
# added line 84, chunk 40
# added line 84, chunk 41
# added line 84, chunk 42
# added line 84, chunk 43
# added line 85, chunk 1
# added line 85, chunk 2
# added line 85, chunk 3
# added line 85, chunk 4
# added line 85, chunk 5
# added line 85, chunk 6
# added line 85, chunk 7
# added line 85, chunk 8
# added line 85, chunk 9
# added line 85, chunk 10
# added line 85, chunk 11
# added line 85, chunk 12
# added line 85, chunk 13
# added line 85, chunk 14
# added line 85, chunk 15
# added line 85, chunk 16
# added line 85, chunk 17
# added line 85, chunk 18
# added line 85, chunk 19
# added line 85, chunk 20
# added line 85, chunk 21
# added line 85, chunk 22
# added line 85, chunk 23
# added line 85, chunk 24
# added line 85, chunk 25
# added line 85, chunk 26
# added line 85, chunk 27
# added line 85, chunk 28
# added line 85, chunk 29
# added line 85, chunk 30
# added line 85, chunk 31
# added line 85, chunk 32
# added line 85, chunk 33
# added line 85, chunk 34
# added line 85, chunk 35
# added line 85, chunk 36
# added line 85, chunk 37
# added line 85, chunk 38
# added line 85, chunk 39
# added line 85, chunk 40
# added line 85, chunk 41
# added line 85, chunk 42
# added line 85, chunk 43
# added line 85, chunk 44
# added line 85, chunk 45
# added line 85, chunk 46
# added line 85, chunk 47
# added line 85, chunk 48
# added line 85, chunk 49
# added line 85, chunk 50
# added line 85, chunk 51
# added line 85, chunk 52
# added line 85, chunk 53
# added line 85, chunk 54
# added line 85, chunk 55
# added line 85, chunk 56
# added line 85, chunk 57
# added line 85, chunk 58
# added line 85, chunk 59
# added line 85, chunk 60
# added line 85, chunk 61
# added line 85, chunk 62
# added line 85, chunk 63
# added line 85, chunk 64
# added line 85, chunk 65
# added line 85, chunk 66
# added line 85, chunk 67
# added line 85, chunk 68
# added line 86, chunk 1
# added line 86, chunk 2
# added line 86, chunk 3
# added line 86, chunk 4
# added line 86, chunk 5
# added line 86, chunk 6
# added line 86, chunk 7
# added line 86, chunk 8
# added line 86, chunk 9
# added line 86, chunk 10
# added line 86, chunk 11
# added line 86, chunk 12
# added line 86, chunk 13
# added line 86, chunk 14
# added line 86, chunk 15
# added line 86, chunk 16
# added line 86, chunk 17
# added line 86, chunk 18
# added line 86, chunk 19
# added line 86, chunk 20
# added line 86, chunk 21
# added line 86, chunk 22
# added line 86, chunk 23
# added line 86, chunk 24
# added line 86, chunk 25
# added line 86, chunk 26
# added line 86, chunk 27
# added line 86, chunk 28
# added line 86, chunk 29
# added line 86, chunk 30
# added line 86, chunk 31
# added line 86, chunk 32
# added line 87, chunk 1
# added line 87, chunk 2
# added line 87, chunk 3
# added line 87, chunk 4
# added line 87, chunk 5
# added line 87, chunk 6
# added line 87, chunk 7
# added line 87, chunk 8
# added line 87, chunk 9
# added line 87, chunk 10
# added line 87, chunk 11
# added line 87, chunk 12
# added line 87, chunk 13
# added line 87, chunk 14
# added line 87, chunk 15
# added line 87, chunk 16
# added line 87, chunk 17
# added line 87, chunk 18
# added line 87, chunk 19
# added line 87, chunk 20
# added line 87, chunk 21
# added line 87, chunk 22
# added line 87, chunk 23
# added line 87, chunk 24
# added line 87, chunk 25
# added line 87, chunk 26
# added line 87, chunk 27
# added line 87, chunk 28
# added line 87, chunk 29
# added line 88, chunk 1
# added line 88, chunk 2
# added line 88, chunk 3
# added line 88, chunk 4
# added line 88, chunk 5
# added line 88, chunk 6
# added line 88, chunk 7
# added line 88, chunk 8
# added line 88, chunk 9
# added line 89, chunk 1
# added line 89, chunk 2
# added line 89, chunk 3
# added line 89, chunk 4
# added line 89, chunk 5
# added line 89, chunk 6
# added line 89, chunk 7
# added line 89, chunk 8
# added line 89, chunk 9
# added line 89, chunk 10
# added line 89, chunk 11
# added line 89, chunk 12
# added line 89, chunk 13
# added line 89, chunk 14
# added line 89, chunk 15
# added line 89, chunk 16
# added line 89, chunk 17
# added line 89, chunk 18
# added line 89, chunk 19
# added line 89, chunk 20
# added line 89, chunk 21
# added line 89, chunk 22
# added line 89, chunk 23
# added line 89, chunk 24
# added line 89, chunk 25
# added line 89, chunk 26
# added line 89, chunk 27
# added line 89, chunk 28
# added line 89, chunk 29
# added line 89, chunk 30
# added line 89, chunk 31
# added line 89, chunk 32
# added line 89, chunk 33
# added line 89, chunk 34
# added line 89, chunk 35
# added line 89, chunk 36
# added line 89, chunk 37
# added line 89, chunk 38
# added line 89, chunk 39
# added line 89, chunk 40
# added line 89, chunk 41
# added line 90, chunk 1
# added line 90, chunk 2
# added line 90, chunk 3
# added line 90, chunk 4
# added line 90, chunk 5
# added line 90, chunk 6
# added line 90, chunk 7
# added line 90, chunk 8
# added line 90, chunk 9
# added line 90, chunk 10
# added line 90, chunk 11
# added line 90, chunk 12
# added line 90, chunk 13
# added line 90, chunk 14
# added line 90, chunk 15
# added line 90, chunk 16
# added line 90, chunk 17
# added line 90, chunk 18
# added line 90, chunk 19
# added line 90, chunk 20
# added line 90, chunk 21
# added line 90, chunk 22
# added line 90, chunk 23
# added line 90, chunk 24
# added line 90, chunk 25
# added line 90, chunk 26
# added line 90, chunk 27
# added line 90, chunk 28
# added line 90, chunk 29
# added line 90, chunk 30
# added line 90, chunk 31
# added line 90, chunk 32
# added line 90, chunk 33
# added line 90, chunk 34
# added line 90, chunk 35
# added line 90, chunk 36
# added line 90, chunk 37
# added line 90, chunk 38
# added line 90, chunk 39
# added line 90, chunk 40
# added line 90, chunk 41
# added line 90, chunk 42
# added line 91, chunk 1
# added line 91, chunk 2
# added line 91, chunk 3
# added line 91, chunk 4
# added line 91, chunk 5
# added line 91, chunk 6
# added line 91, chunk 7
# added line 91, chunk 8
# added line 91, chunk 9
# added line 91, chunk 10
# added line 91, chunk 11
# added line 91, chunk 12
# added line 91, chunk 13
# added line 91, chunk 14
# added line 91, chunk 15
# added line 91, chunk 16
# added line 91, chunk 17
# added line 91, chunk 18
# added line 91, chunk 19
# added line 91, chunk 20
# added line 91, chunk 21
# added line 91, chunk 22
# added line 91, chunk 23
# added line 91, chunk 24
# added line 91, chunk 25
# added line 91, chunk 26
# added line 91, chunk 27
# added line 91, chunk 28
# added line 91, chunk 29
# added line 91, chunk 30
# added line 91, chunk 31
# added line 91, chunk 32
# added line 91, chunk 33
# added line 91, chunk 34
# added line 91, chunk 35
# added line 91, chunk 36
# added line 91, chunk 37
# added line 91, chunk 38
# added line 92, chunk 1
# added line 92, chunk 2
# added line 92, chunk 3
# added line 92, chunk 4
# added line 92, chunk 5
# added line 92, chunk 6
# added line 92, chunk 7
# added line 92, chunk 8
# added line 92, chunk 9
# added line 92, chunk 10
# added line 92, chunk 11
# added line 92, chunk 12
# added line 92, chunk 13
# added line 92, chunk 14
# added line 92, chunk 15
# added line 92, chunk 16
# added line 92, chunk 17
# added line 92, chunk 18
# added line 92, chunk 19
# added line 92, chunk 20
# added line 92, chunk 21
# added line 92, chunk 22
# added line 92, chunk 23
# added line 92, chunk 24
# added line 92, chunk 25
# added line 92, chunk 26
# added line 92, chunk 27
# added line 92, chunk 28
# added line 92, chunk 29
# added line 92, chunk 30
# added line 92, chunk 31
# added line 93, chunk 1
# added line 93, chunk 2
# added line 93, chunk 3
# added line 93, chunk 4
# added line 93, chunk 5
# added line 93, chunk 6
# added line 93, chunk 7
# added line 93, chunk 8
# added line 93, chunk 9
# added line 93, chunk 10
# added line 93, chunk 11
# added line 93, chunk 12
# added line 93, chunk 13
# added line 93, chunk 14
# added line 93, chunk 15
# added line 93, chunk 16
# added line 93, chunk 17
# added line 93, chunk 18
# added line 93, chunk 19
# added line 93, chunk 20
# added line 93, chunk 21
# added line 93, chunk 22
# added line 93, chunk 23
# added line 93, chunk 24
# added line 93, chunk 25
# added line 93, chunk 26
# added line 93, chunk 27
# added line 93, chunk 28
# added line 93, chunk 29
# added line 93, chunk 30
# added line 93, chunk 31
# added line 93, chunk 32
# added line 94, chunk 1
# added line 94, chunk 2
# added line 94, chunk 3
# added line 94, chunk 4
# added line 94, chunk 5
# added line 94, chunk 6
# added line 94, chunk 7
# added line 94, chunk 8
# added line 94, chunk 9
# added line 94, chunk 10
# added line 94, chunk 11
# added line 94, chunk 12
# added line 94, chunk 13
# added line 94, chunk 14
# added line 94, chunk 15
# added line 94, chunk 16
# added line 94, chunk 17
# added line 94, chunk 18
# added line 94, chunk 19
# added line 94, chunk 20
# added line 94, chunk 21
# added line 94, chunk 22
# added line 94, chunk 23
# added line 94, chunk 24
# added line 94, chunk 25
# added line 94, chunk 26
# added line 94, chunk 27
# added line 94, chunk 28
# added line 94, chunk 29
# added line 94, chunk 30
# added line 94, chunk 31
# added line 94, chunk 32
# added line 94, chunk 33
# added line 94, chunk 34
# added line 94, chunk 35
# added line 94, chunk 36
# added line 94, chunk 37
# added line 94, chunk 38
# added line 94, chunk 39
# added line 94, chunk 40
# added line 94, chunk 41
# added line 94, chunk 42
# added line 94, chunk 43
# added line 94, chunk 44
# added line 94, chunk 45
# added line 94, chunk 46
# added line 94, chunk 47
# added line 94, chunk 48
# added line 94, chunk 49
# added line 94, chunk 50
# added line 94, chunk 51
# added line 94, chunk 52
# added line 95, chunk 1
# added line 95, chunk 2
# added line 95, chunk 3
# added line 95, chunk 4
# added line 95, chunk 5
# added line 95, chunk 6
# added line 95, chunk 7
# added line 95, chunk 8
# added line 95, chunk 9
# added line 95, chunk 10
# added line 95, chunk 11
# added line 95, chunk 12
# added line 95, chunk 13
# added line 95, chunk 14
# added line 95, chunk 15
# added line 95, chunk 16
# added line 95, chunk 17
# added line 95, chunk 18
# added line 95, chunk 19
# added line 95, chunk 20
# added line 95, chunk 21
# added line 95, chunk 22
# added line 95, chunk 23
# added line 95, chunk 24
# added line 95, chunk 25
# added line 95, chunk 26
# added line 96, chunk 1
# added line 96, chunk 2
# added line 96, chunk 3
# added line 96, chunk 4
# added line 96, chunk 5
# added line 96, chunk 6
# added line 96, chunk 7
# added line 96, chunk 8
# added line 96, chunk 9
# added line 96, chunk 10
# added line 96, chunk 11
# added line 96, chunk 12
# added line 96, chunk 13
# added line 96, chunk 14
# added line 96, chunk 15
# added line 96, chunk 16
# added line 96, chunk 17
# added line 96, chunk 18
# added line 96, chunk 19
# added line 96, chunk 20
# added line 96, chunk 21
# added line 96, chunk 22
# added line 96, chunk 23
# added line 96, chunk 24
# added line 96, chunk 25
# added line 96, chunk 26
# added line 96, chunk 27
# added line 96, chunk 28
# added line 96, chunk 29
# added line 96, chunk 30
# added line 96, chunk 31
# added line 96, chunk 32
# added line 96, chunk 33
# added line 96, chunk 34
# added line 96, chunk 35
# added line 96, chunk 36
# added line 96, chunk 37
# added line 96, chunk 38
# added line 96, chunk 39
# added line 96, chunk 40
# added line 96, chunk 41
# added line 96, chunk 42
# added line 96, chunk 43
# added line 97, chunk 1
# added line 97, chunk 2
# added line 97, chunk 3
# added line 97, chunk 4
# added line 97, chunk 5
# added line 97, chunk 6
# added line 97, chunk 7
# added line 97, chunk 8
# added line 97, chunk 9
# added line 97, chunk 10
# added line 97, chunk 11
# added line 97, chunk 12
# added line 97, chunk 13
# added line 97, chunk 14
# added line 97, chunk 15
# added line 97, chunk 16
# added line 97, chunk 17
# added line 97, chunk 18
# added line 97, chunk 19
# added line 97, chunk 20
# added line 97, chunk 21
# added line 97, chunk 22
# added line 97, chunk 23
# added line 97, chunk 24
# added line 97, chunk 25
# added line 97, chunk 26
# added line 97, chunk 27
# added line 97, chunk 28
# added line 97, chunk 29
# added line 97, chunk 30
# added line 97, chunk 31
# added line 97, chunk 32
# added line 97, chunk 33
# added line 97, chunk 34
# added line 97, chunk 35
# added line 97, chunk 36
# added line 97, chunk 37
# added line 97, chunk 38
# added line 98, chunk 1
# added line 98, chunk 2
# added line 98, chunk 3
# added line 98, chunk 4
# added line 98, chunk 5
# added line 98, chunk 6
# added line 98, chunk 7
# added line 98, chunk 8
# added line 98, chunk 9
# added line 98, chunk 10
# added line 98, chunk 11
# added line 98, chunk 12
# added line 98, chunk 13
# added line 98, chunk 14
# added line 98, chunk 15
# added line 98, chunk 16
# added line 98, chunk 17
# added line 98, chunk 18
# added line 98, chunk 19
# added line 98, chunk 20
# added line 98, chunk 21
# added line 98, chunk 22
# added line 98, chunk 23
# added line 98, chunk 24
# added line 98, chunk 25
# added line 98, chunk 26
# added line 98, chunk 27
# added line 98, chunk 28
# added line 98, chunk 29
# added line 98, chunk 30
# added line 98, chunk 31
# added line 98, chunk 32
# added line 98, chunk 33
# added line 98, chunk 34
# added line 98, chunk 35
# added line 99, chunk 1
# added line 99, chunk 2
# added line 99, chunk 3
# added line 99, chunk 4
# added line 99, chunk 5
# added line 99, chunk 6
# added line 99, chunk 7
# added line 99, chunk 8
# added line 99, chunk 9
# added line 99, chunk 10
# added line 99, chunk 11
# added line 99, chunk 12
# added line 99, chunk 13
# added line 99, chunk 14
# added line 99, chunk 15
# added line 99, chunk 16
# added line 99, chunk 17
# added line 99, chunk 18
# added line 99, chunk 19
# added line 99, chunk 20
# added line 99, chunk 21
# added line 99, chunk 22
# added line 99, chunk 23
# added line 99, chunk 24
# added line 99, chunk 25
# added line 99, chunk 26
# added line 99, chunk 27
# added line 99, chunk 28
# added line 99, chunk 29
# added line 99, chunk 30
# added line 100, chunk 1
# added line 100, chunk 2
# added line 100, chunk 3
# added line 100, chunk 4
# added line 100, chunk 5
# added line 100, chunk 6
# added line 100, chunk 7
# added line 100, chunk 8
# added line 100, chunk 9
# added line 100, chunk 10
# added line 100, chunk 11
# added line 100, chunk 12
# added line 100, chunk 13
# added line 100, chunk 14
# added line 100, chunk 15
# added line 100, chunk 16
# added line 100, chunk 17
# added line 100, chunk 18
# added line 100, chunk 19
# added line 100, chunk 20
# added line 100, chunk 21
# added line 100, chunk 22
# added line 100, chunk 23

# %%
# check total number of entries
query = f"""
    {{
      Aggregate {{
        {'Manuscript'} {{
          meta {{
            count
          }}
        }}
      }}
    }}
    """
result = client.query.raw(query)
print(result['data']['Aggregate']['Manuscript'][0]['meta']['count'])
# Out:
# 3658

# %%
# test query
response = (
    client.query
    .get("Manuscript", ["text"])
    .with_near_text({
        "concepts": ["estradiol impact on women's fear"]
    })
    .with_limit(5)
    .with_additional(["distance", "certainty"])
    .do()
)

print(json.dumps(response["data"]["Get"]["Manuscript"]))
# Out:
# [{"_additional": {"certainty": 0.8103974461555481, "distance": 0.3792051}, "text": "heir contributions to fear extinction behavior.\n\nClinical translation\n\nThe present study is the first to examine the network-level effects of estradiol on fear extinction from extinction learning to extinction recall; as such, it provides critical insight into the brain networks underlying anxiety and fear-based disorders in women. Our data support the growing literature indicating that given the relationship between naturally fluctuating endogenous estradiol and fear extinction memory, the success of psychiatric treatment (efficacy, duration, efficiency) may depend on gonadal hormone status (Wegerer et al., 2014; Glover et al., 2015; Pineles et al., 2016). Based on these data, estradiol may strengthen the consolidation of extinction memory via modulation of the amygdalar nuclei by the IL. This has powerful implications for improved treatment targets and enhanced efficacy of treatments dependent on fear extinction processes, such as exposure therapy.\n\nFuture directions\n\nEvidence suggesting that estradiol can strengthen extinction memory consolidation is important for improving therapeutic outcomes for individuals suffering from PTSD and other fear and anxiety-related disorders. However, the long-term maintenance of these effects on extinction memory has yet to be determined, and their durability is an important consideration for the potential augmentation of therapy with estradiol. We have identified brain regions and nuclei that are modified by estradiol and associated with its effects on behavior at critical time points (during extinction learning and during extinction recall); however, it is unclear which point of the extinction session is represented by the c-fos expression reported in this study as early and late extinction may induce differential effects. There is also still a need to investigate estradiol\u2019s effects on fear extinction circuitry during memory consolidation to bridge the gap of neuronal change and plasticity that may occur between day 2 and day 3. To further explore this issue, examining the "}, {"_additional": {"certainty": 0.8098154067993164, "distance": 0.3803692}, "text": "ministration of either estradiol (E2) or vehicle prior to extinction training. Extinction memory recall was then tested 24h later (day 3). We measured immediate early gene c-fos expression within the extinction network during fear extinction learning and extinction recall. During extinction learning, E2 treatment increased centrolateral amygdala (CeL) c-fos activity and reduced lateral amygdala (LA) activity relative to vehicle. During extinction recall, E2-treated rats exhibited reduced c-fos expression in the centromedial amygdala (CeM). There were no group differences in c-fos expression within the medial prefrontal cortex and dorsal hippocampus. Examining c-fos ratios with the infralimbic cortex (IL) revealed that despite the lack of group differences within the IL, E2 treatment induced greater IL activity relative to both the prelimbic cortex (PL) and central amygdala (CeA) activity during extinction memory recall. Only the relationship between IL and CeA activity positively correlated with extinction retention. In conclusion, estradiol appears to modify interactions between the IL and CeA in females, shifting from stronger amygdalar modulation of fear during extinction learning to stronger IL control during extinction recall.\n\nGraphical abstract\n\nEstradiol\u2019s modulatory effects on fear extinction memory consolidation may be driven by the IL-amygdala circuit of the fear network. With increasing estradiol levels, neuronal activation shifts during extinction from stronger CeA to IL activity to stronger IL to CeA activity, correlating with more and less fear during extinction recall, respectively.\n\nsex differences\nestradiol\ninfralimbic cortex\ncentral amygdala\nc-fos\nfear extinction\nestrous cycle\ncentromedial amygdala\nfe ...
